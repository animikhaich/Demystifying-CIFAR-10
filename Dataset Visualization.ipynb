# %% [markdown]
# ## Load Dataset

# %%
import matplotlib.pyplot as plt
import numpy as np
import os

from utils import load_cifar_train, load_cifar_test, get_cifar_label_names
from utils import visualize_batch

# %%
root_path = "../data/cifar-10-batches-py"

x_train, y_train = load_cifar_train(root_path)
x_test, y_test = load_cifar_test(root_path)
label_names = get_cifar_label_names(root_path)

print(f"Train Dataset: Train Images - {x_train.shape} | Train Labels - {y_train.shape}")
print(f"Test Dataset: Test Images - {x_test.shape} | Test Labels - {y_test.shape}")
print(f"Labels: {label_names}")
# Out:
# Train Dataset: Train Images - (10000, 32, 32, 3) | Train Labels - (10000,)
# Test Dataset: Test Images - (10000, 32, 32, 3) | Test Labels - (10000,)
# Labels: ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %% [markdown]
# ## Dataset Visualize Images

# %%
visualize_batch(x_train, y_train, label_names, title="Train Dataset")
visualize_batch(x_test, y_test, label_names, title="Test Dataset")
